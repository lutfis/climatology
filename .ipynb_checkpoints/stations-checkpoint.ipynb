# %%
import matplotlib.pyplot as plt
import mplleaflet
import pandas as pd
import numpy as np

# %%
stations = pd.read_fwf('ghcnd-stations.txt', header=None)
stations = stations.drop(stations.columns[[5, 6, 7]], axis=1)
stations.rename(columns={0: 'ID',1:'LATITUDE',2:'LONGITUDE',3:'ELEVATION',4:'NAME'}, inplace=True)

# %%
filter_lat = stations[stations['LATITUDE']>36]
filter_lat = filter_lat[filter_lat['LATITUDE']<41]
filter = filter_lat[filter_lat['LONGITUDE']> 26]
filter = filter[filter['LONGITUDE']< 44]
filter
# Out:
#                 ID  LATITUDE  LONGITUDE  ELEVATION                     NAME
# 171    AM000037682   40.7830    43.8330     1866.0                   AMASIA
# 172    AM000037683   40.8670    43.9500     1798.0        JABJUR-IN-ARMENIA
# 173    AM000037686   40.7800    43.8300     1523.0                    GUMRI
# 188    AM000037772   40.4000    43.9000     1637.0                    TALIN
# 189    AM000037773   40.5000    43.9000     2151.0                 GARNOVIT
# 190    AM000037774   40.3170    43.6670     1255.0                  ARAGATS
# 34426  GR000167230   37.7000    26.9167        2.0            SAMOS AIRPORT
# 34431  GRE00105240   38.3331    26.1331        4.0                    CHIOS
# 45418  SY000040001   37.0500    41.2200      455.0                 KAMISHLI
# 45421  SYE00147759   36.8200    38.0000      350.0                 JARABLUS
# 45422  SYE00147760   36.1800    37.2200      390.0                   ALEPPO
# ...

# %%
istanbul = 'TU000017062'

# %%
lons = filter['LONGITUDE']
lats = filter['LATITUDE']
plt.figure(figsize=(8,8))
plt.scatter(lons, lats, c='r', alpha=0.7, s=200)
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="480"></iframe>

# %%
df = pd.read_fwf('TU000017062.txt', header=None)
df
# Out:
#                               0       1       2       3        4       5   \
# 0     TU000017062192901TMAX  155  G  164  G  170  G  146   G  138  G  121
# 1     TU000017062192901TMIN   97  G  102  G   92  G   90   G   74  G   51
# 2     TU000017062192901PRCP-9999   -9999   -9999   -9999       80  I   50
# 3     TU000017062192902TMAX   22  G   -9  G  -50  G  -35   G  -34  G   19
# 4     TU000017062192902TMIN  -23  G  -59  G  -82  G  -60   G  -63  G  -60
# 5     TU000017062192902PRCP   20  I   10  I    0  I-9999    -9999   -9999
# 6     TU000017062192903TMAX   50  G   19  G    9  G   50   G  103  G   62
# 7     TU000017062192903TMIN    7  G  -27  G  -53  G  111  IG   17  G    5
# 8     TU000017062192903PRCP   30  I   20  I   10  I   10   I-9999     190
# 9     TU000017062192904TMAX  130  G  170  G  170  G  190   G  121  G  110
# 10    TU000017062192904TMIN    0  G   49  G  105  G   97   G   32  G   39
# 11    TU000017062192904PRCP-9999       0  I-9999   -9999       30  I  160
# ...

# %%
#it is really difficult to read this data in. it requires a dedicated research and time which i dont have right now.
